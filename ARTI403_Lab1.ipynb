# %%
# !pip install numpy opencv-python pillow matplotlib scikit-image scipy
# Out:
# Requirement already satisfied: numpy in D:\ANACONDA\Lib\site-packages (2.4.6)
# Requirement already satisfied: opencv-python in D:\ANACONDA\Lib\site-packages (5.0.0.93)
# Requirement already satisfied: pillow in D:\ANACONDA\Lib\site-packages (12.3.0)
# Requirement already satisfied: matplotlib in D:\ANACONDA\Lib\site-packages (3.11.0)
# Requirement already satisfied: scikit-image in D:\ANACONDA\Lib\site-packages (0.26.0)
# Requirement already satisfied: scipy in D:\ANACONDA\Lib\site-packages (1.18.0)
# Requirement already satisfied: contourpy>=1.0.1 in D:\ANACONDA\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in D:\ANACONDA\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in D:\ANACONDA\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in D:\ANACONDA\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=3 in D:\ANACONDA\Lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: networkx>=3.0 in D:\ANACONDA\Lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in D:\ANACONDA\Lib\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in D:\ANACONDA\Lib\site-packages (from scikit-image) (2026.6.1)
# Requirement already satisfied: lazy-loader>=0.4 in D:\ANACONDA\Lib\site-packages (from scikit-image) (0.5)
# Requirement already satisfied: six>=1.5 in .\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('images/cameraman.tif')
plt.figure()
plt.imshow(img, cmap='gray')
plt.title("Cameraman")
plt.axis('off')
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

img2_gray = Image.open('images/lena_gray_256.tif').convert('L')

plt.figure()
plt.imshow(img2_gray, cmap='gray')
plt.title("Lena (Grayscale)")
plt.axis('off')
plt.show()

# %%
cv2.imwrite('new_image.jpg', img)
# Out:
# True

# %%
print(img.shape) 
print(img) 
import numpy as np
img_array = np.array(img2)
print(img_array.shape)
print(img_array)
# Out:
# (512, 512, 3)
# [[[200 200 200]
#   [200 200 200]
#   [200 200 200]
#   ...
#   [189 189 189]
#   [190 190 190]
#   [190 190 190]]
#
#  [[200 200 200]
#   [199 199 199]
#   [199 199 199]
#   ...
#   [190 190 190]
#   [190 190 190]
#   [190 190 190]]
#
#  [[199 199 199]
#   [199 199 199]
#   [199 199 199]
#   ...
#   [190 190 190]
#   [190 190 190]
#   [190 190 190]]
#
#  ...
#
#  [[ 25  25  25]
#   [ 25  25  25]
#   [ 27  27  27]
#   ...
#   [139 139 139]
#   [122 122 122]
#   [147 147 147]]
#
#  [[ 25  25  25]
#   [ 25  25  25]
#   [ 26  26  26]
#   ...
#   [158 158 158]
#   [141 141 141]
#   [168 168 168]]
#
#  [[ 25  25  25]
#   [ 25  25  25]
#   [ 27  27  27]
#   ...
#   [151 151 151]
#   [152 152 152]
#   [149 149 149]]]
# (512, 512, 3)
# [[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  ...
#
#  [[ 84  18  60]
#   [ 84  18  60]
#   [ 92  27  58]
#   ...
#   [173  73  84]
#   [172  68  76]
#   [177  62  79]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]]
